# %% [markdown]
# <a href="https://colab.research.google.com/github/Adi11cr7/BRATS-Segmentation/blob/main/BRATS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install split-folders
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import zipfile
import os

# zip_ref = zipfile.ZipFile('/content/drive/MyDrive/BRATS_Segmentation/BRATS2020.zip', 'r') #Opens the zip file in read mode
# zip_ref.extractall('/tmp') #Extracts the files into the /tmp folder
# zip_ref.close()

# !unzip '/content/drive/MyDrive/BRATS_Segmentation/BRATS.zip'
# Out:
# Archive:  /content/drive/MyDrive/BRATS_Segmentation/BRATS.zip
# warning [/content/drive/MyDrive/BRATS_Segmentation/BRATS.zip]:  214065603 extra bytes at beginning or within zipfile
#   (attempting to process anyway)
# error [/content/drive/MyDrive/BRATS_Segmentation/BRATS.zip]:  start of central directory not found;
#   zipfile corrupt.
#   (please check that you have transferred or created the zipfile in the
#   appropriate BINARY mode and that you have compiled UnZip properly)

# %%
# !pwd
# Out:
# /content

# %%
# !python get_data_ready.py
# Out:
# 2023-04-28 18:28:48.761306: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-28 18:28:49.627572: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 367.0
# [0 1 2 4]
# [0 1 2 3]
# Figure(1200x800)
# Figure(1200x800)
# /content/get_data_ready.py:134: DeprecationWarning: <tifffile.imsave> is deprecated. Use tifffile.imwrite
#   imsave('BraTS2020_TrainingData/combined255.tif', combined_x)
# Now preparing image and masks number:  0
# Save Me
# Now preparing image and masks number:  1
# Save Me
# Now preparing image and masks number:  2
# Save Me
# Now preparing image and masks number:  3
# Save Me
# Now preparing image and masks number:  4
# I am useless
# Now preparing image and masks number:  5
# ...

# %%
# %matplotlib inline 
# !python custom_data_gen.py
# Out:
# Figure(1200x800)

# %%
# !pip3 install -U segmentation-models-3D
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.5/69.5 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.6 MB/s eta 0:00:00
# ...

# %%
# !python train.py
# Out:
# Figure(1200x800)
# 2023-04-28 19:04:49.961040: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-28 19:04:51.034610: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Figure(1200x800)
# 0
# /content/train.py:79: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 1
# /content/train.py:79: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(conts_dict, ignore_index=True)
# 2
# ...
